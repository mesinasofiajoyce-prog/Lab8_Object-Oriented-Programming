# %%
class Car:
  def __init__(self, brand, model, year):
    self.brand = brand
    self.model = model
    self.year = year

  def display_info(self):
    return f"{self.year} {self.brand} {self.model}"

# Step 2: Create an object of the Car class
my_car = Car("Toyota", "Corolla", 2022)

# Step 3: Print the car details using the method
print(my_car.display_info())
# Out:
# 2022 Toyota Corolla

# %%
class Laptop:
    def __init__(self, brand, processor, ram):
        self.brand = brand
        self.processor = processor
        self.ram = ram

    def get_specs(self):
        return f"Laptop: {self.brand} | Processor: {self.processor} | RAM: {self.ram}"

my_laptop = Laptop("Acer Aspire 7", "Intel i5", "16GB")

print(my_laptop.get_specs())
# Out:
# Laptop: Acer Aspire 7 | Processor: Intel i5 | RAM: 16GB

# %%
# Step 1: Define a class with private attributes
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self._balance = balance  # Private attribute

    def deposit(self, amount):
        self._balance += amount
        return f"New balance: ${self._balance}"

    def get_balance(self):
        return f"Balance: ${self._balance}"

# Step 2: Create an object and test encapsulation
account = BankAccount("Alice", 5000)

# Step 3: Deposit money and display the updated balance
print(account.deposit(1500))
print(account.get_balance())
# Out:
# New balance: $6500
# Balance: $6500

# %%
class StudentRecord:
    def __init__(self):
        self._grades = []

    def add_grade(self, grade):
        self._grades.append(grade)

    def get_grades(self):
        return self._grades

student = StudentRecord()

student.add_grade(85)
student.add_grade(90)
student.add_grade(78)

print(student.get_grades())
# Out:
# [85, 90, 78]

# %%
# Step 1: Define a base class
class Person:
    def __init__(self, name):
        self.name = name

    def introduce(self):
        return f"Hi, I'm {self.name}."

# Step 2: Define a subclass that inherits from Person
class Student(Person):
    def introduce(self):
        return f"Hi, I'm {self.name}, and I'm a student."

# Step 3: Create objects and call methods
person = Person("Allen")
student = Student("Mark")

print(person.introduce())
print(student.introduce())
# Out:
# Hi, I'm Allen.
# Hi, I'm Mark, and I'm a student.

# %%
class Device:
    def __init__(self, device_name):
        self.device_name = device_name

    def power_on(self):
        return f"{self.device_name} is powering on."

class Smartphone(Device):
    def power_on(self):
        return f"{self.device_name} is booting up (smartphone)."

device = Device("Generic Device")
phone = Smartphone("iPhone")

print(device.power_on())
print(phone.power_on())
# Out:
# Generic Device is powering on.
# iPhone is booting up (smartphone).

# %%
# Step 1: Define a base class
class Shape:
    def area(self):
        return "Calculating area ... "

# Step 2: Define subclasses with their implementations
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Step 3: Create objects and call their methods
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Circle area: {circle.area()}")
print(f"Rectangle area: {rectangle.area()}")
# Out:
# Circle area: 78.5
# Rectangle area: 24

# %%
class Device:
    def power_on(self):
        return "Device is powering on."

class Smartphone(Device):
    def power_on(self):
        return "Smartphone is booting up with mobile OS."

class Laptop(Device):
    def power_on(self):
        return "Laptop is starting up with desktop OS."

def start_device(device):
    print(device.power_on())

phone = Smartphone()
laptop = Laptop()

start_device(phone)
start_device(laptop)
# Out:
# Smartphone is booting up with mobile OS.
# Laptop is starting up with desktop OS.

# %%
# Step 1: Import the datetime module
import datetime

# Step 2: Create an object for the current date and time
current_time = datetime.datetime.now()

# Step 3: Print the formatted date and time
print("Current Date and Time:", current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current Date and Time: 2026-05-03 06:33:20

# %%
import random
import os

rand_num = random.random()

os_name = os.name

print("Random number (0 to 1):", rand_num)
print("Operating System:", os_name)
# Out:
# Random number (0 to 1): 0.3524035474128451
# Operating System: posix

# %%
# Step 1: Define a class with a static method
class MathOperations:
    @staticmethod
    def square(num):
        return num * num

# Step 2: Get user input
user_input = int(input("Enter a number to square: "))

# Step 3: Call the static method with user input
result = MathOperations.square(user_input)

# Step 4: Print the result
print("Square of", user_input, ":", result)
# Out:
# Enter a number to square: 16
# Square of 16 : 256

# %%
class TemperatureConverter:
    @staticmethod
    def celsius_to_fahrenheit(celsius):
        return (celsius * 9/5) + 32

celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = TemperatureConverter.celsius_to_fahrenheit(celsius)

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 187
# Temperature in Fahrenheit: 368.6

# %%
# Step 1: Define a class with overloaded operators
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def __add__(self, other):
        return BankAccount(self.balance + other.balance)

# Step 2: Create account objects and add their balances
account1 = BankAccount(5000)
account2 = BankAccount(3000)

total_balance = account1 + account2  # Combines the balances

# Step 3: Print the result
print(f"Total Balance: P{total_balance.balance}")
# Out:
# Total Balance: P8000

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overload +
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # Overload -
    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)

    def display(self):
        return f"({self.x}, {self.y})"

# Create vector instances
v1 = Vector(4, 7)
v2 = Vector(2, 3)

# Vector addition and subtraction
sum_vector = v1 + v2
diff_vector = v1 - v2

# Print results
print("Vector 1:", v1.display())
print("Vector 2:", v2.display())
print("Addition:", sum_vector.display())
print("Subtraction:", diff_vector.display())
# Out:
# Vector 1: (4, 7)
# Vector 2: (2, 3)
# Addition: (6, 10)
# Subtraction: (2, 4)

# %%
from abc import ABC, abstractmethod

# Step 1: Define an abstract class
class Appliance(ABC):
    @abstractmethod
    def turn_on(self):
        pass

# Step 2: Define a subclass implementing the abstract method
class WashingMachine(Appliance):
    def turn_on(self):
        return "Washing machine is now running."

# Step 3: Create an object of the subclass and call the method
wm = WashingMachine()
print(wm.turn_on())
# Out:
# Washing machine is now running.

# %%
from abc import ABC, abstractmethod

class Appliance(ABC):
    @abstractmethod
    def turn_on(self):
        pass

class Refrigerator(Appliance):
    def turn_on(self):
        return "Refrigerator is now cooling."

fridge = Refrigerator()
print(fridge.turn_on())
# Out:
# Refrigerator is now cooling.

# %%
# Step 1: Define multiple classes
class A:
    def show(self):
        return "Class A"

class B(A):
    def show(self):
        return "Class B"

class C(A):
    def show(self):
        return "Class C"

class D(B, C):
    pass  # Inherits show() based on MRO

# Step 2: Create an object of class D and call the method
obj = D()
print(obj.show())

# Output depends on MRO
# Out:
# Class B

# %%
class A:
    def show(self):
        return "Class A"

class B(A):
    def show(self):
        return "Class B"

class C(A):
    def show(self):
        return "Class C"

class D(B, C):
    pass

obj = D()
print(obj.show())

print(D.mro())
# Out:
# Class B
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]
